# %%
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"G:\B.E\TE VI\DSBDA\DataSets\forestfires.csv")

# %%
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# X        0
# Y        0
# month    0
# day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# temp     0
# RH       0
# wind     0
# rain     0
# area     0
# dtype: int64

# %%
# 1.Pie chart

# %%
sizes = [df['temp'].mean(), df['wind'].mean(), df['rain'].mean()]
explodes = (0.1, 0, 0)
labels = 'temp','wind','rain'
colors = ('red', 'blue', 'yellow')
plt.pie(sizes, explode=explodes, labels=labels, colors=colors, autopct='%1.1f%%',shadow=True, startangle=140)
plt.title('Average Weather')
plt.show()

# %%
# 2.Bar Plot

# %%
h = df.iloc[1:21,8]
y_pos = np.arange(len(h))
v = range(1, 21)
plt.bar(y_pos, h, align='center', alpha=0.5)
plt.xticks(y_pos, v)
plt.title('Temperature in last 20 days')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.show()

# %%
#3. Histogram Plot

# %%
e = df.iloc[1:25,8]
plt.hist(e, bins='auto')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Histogram for Temperature Analysis')
plt.show()

# %%
#4 Line Plot

# %%
l1 = df.iloc[1:20,8]
l2 = df.iloc[1:20,10]
plt.plot(l1, label='Temperature', color='red', marker='*',linestyle='dotted')
plt.plot(l2, label='wind', color='green', marker='o', linestyle='dashed')
plt.ylim(0,60)
plt.title('Temperature vs Wind')
plt.xlabel('Temp and Wind')
plt.ylabel('values')
plt.legend()

# %%
#5 Scatter Plot

# %%
x = df.iloc[1:80,8]
y = df.iloc[1:80,10]
plt.scatter(x,y)
plt.title('Temp vs Wind Scatter plot')
plt.xlabel('temp')
plt.ylabel('Wind')
plt.show()

# %%
#6 BOX Plot

# %%
df.boxplot(by='month', column=['temp'])
plt.show()

# %%
#7. Pair Plot

# %%
sns.pairplot(df)
plt.show()

# %%
# 8.HeatMap

# %%
df.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
df2 = df[['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
       'wind', 'rain', 'area']]
sns.heatmap(df2)
plt.show()

# %%
# 9. WordCloud

# %%
text = 'Explore the world, embrace diversity, chase dreams, ignite passion, celebrate beauty, unravel mysteries, paint masterpieces, and let imagination soar'

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.Figure(figsize=(7,5), dpi=150, facecolor='g')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
