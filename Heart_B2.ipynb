# %%
import pandas as pd

# %%
df = pd.read_csv(r"G:\B.E\TE VI\DSBDA\DataSets\Heart.csv")

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
df.shape
# Out:
# (303, 15)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
#DATA CLEANING

# %%
df = df.drop(columns='Unnamed: 0')
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df['Ca'] = df['Ca'].fillna(df['Ca'].mean())

# %%
df['Thal'] = df['Thal'].fillna(df['Thal'].mode()[0])

# %%
df.isna().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
#DATA INTEGRATION

# %%
subset1 = df.iloc[:,[0,3]]
subset1
# Out:
#      Age  RestBP
# 0     63     145
# 1     67     160
# 2     67     120
# 3     37     130
# 4     41     130
# ..   ...     ...
# 298   45     110
# 299   68     144
# 300   57     130
# 301   57     130
# 302   38     138
#
# [303 rows x 2 columns]

# %%
subset2 = df.iloc[:,[1,2]]
subset2
# Out:
#      Sex     ChestPain
# 0      1       typical
# 1      1  asymptomatic
# 2      1  asymptomatic
# 3      1    nonanginal
# 4      0    nontypical
# ..   ...           ...
# 298    1       typical
# 299    1  asymptomatic
# 300    1  asymptomatic
# 301    0    nontypical
# 302    1    nonanginal
#
# [303 rows x 2 columns]

# %%
integrated_DF = pd.concat([subset1,subset2])
integrated_DF
# Out:
#       Age  RestBP  Sex     ChestPain
# 0    63.0   145.0  NaN           NaN
# 1    67.0   160.0  NaN           NaN
# 2    67.0   120.0  NaN           NaN
# 3    37.0   130.0  NaN           NaN
# 4    41.0   130.0  NaN           NaN
# ..    ...     ...  ...           ...
# 298   NaN     NaN  1.0       typical
# 299   NaN     NaN  1.0  asymptomatic
# 300   NaN     NaN  1.0  asymptomatic
# 301   NaN     NaN  0.0    nontypical
# 302   NaN     NaN  1.0    nonanginal
#
# [606 rows x 4 columns]

# %%
#DATA TRANSFORMATION - LabelEncoding

# %%
from sklearn import preprocessing
df['Thal'] = preprocessing.LabelEncoder().fit_transform(df['Thal'])
df['Thal'].unique()
# Out:
# array([0, 1, 2])

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope        Ca  Thal  AHD
# 0        2.3      3  0.000000     0   No
# 1        1.5      2  3.000000     1  Yes
# ...

# %%
#MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x = df[['Age']]
y = df[['RestBP']]

# %%
x
# Out:
#      Age
# 0     63
# 1     67
# 2     67
# 3     37
# 4     41
# ..   ...
# 298   45
# 299   68
# 300   57
# 301   57
# 302   38
#
# [303 rows x 1 columns]

# %%
y
# Out:
#      RestBP
# 0       145
# 1       160
# 2       120
# 3       130
# 4       130
# ..      ...
# 298     110
# 299     144
# 300     130
# 301     130
# 302     138
#
# [303 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2)

# %%
x_train
# Out:
#      Age
# 59    51
# 135   55
# 202   57
# 176   52
# 184   60
# 243   61
# 200   50
# 47    50
# 220   41
# 63    54
# 298   45
# 297   57
# 258   70
# 76    60
# 145   47
# 104   49
# 123   55
# 58    54
# 124   65
# 188   54
# 255   42
# 133   51
# 105   54
# 50    41
# 26    58
# 278   57
# 22    58
# 17    54
# 299   68
# 87    53
# 114   62
# 108   61
# 181   56
# 203   64
# 94    63
# 82    39
# 60    51
# 237   46
# 137   62
# 49    53
# 229   66
# 270   61
# 91    62
# 75    65
# 136   70
# 0     63
# 6     62
# 83    68
# 207   50
# 151   42
# 191   51
# 194   68
# 28    43
# 65    60
# 291   55
# 230   52
# 9     53
# 141   59
# 262   60
# 221   54

# %%
y_train
# Out:
#      RestBP
# 59      125
# 135     135
# 202     150
# 176     108
# 184     158
# 243     134
# 200     110
# 47      150
# 220     112
# 63      135
# 298     110
# 297     140
# 258     156
# 76      125
# 145     108
# 104     120
# 123     140
# 58      125
# 124     138
# 188     192
# 255     120
# 133     140
# 105     108
# 50      105
# 26      120
# 278     154
# 22      120
# 17      140
# 299     144
# 87      128
# 114     130
# 108     120
# 181     134
# 203     140
# 94      135
# 82      140
# 60      130
# 237     120
# 137     120
# 49      130
# 229     112
# 270     140
# 91      160
# 75      160
# 136     145
# 0       145
# 6       140
# 83      180
# 207     144
# 151     102
# 191     140
# 194     120
# 28      150
# 65      145
# 291     132
# 230     136
# 9       140
# 141     170
# 262     150
# 221     108

# %%
model = LinearRegression().fit(x_train,y_train) 
model
# Out:
# LinearRegression()

# %%
R_score = model.score(x_train,y_train)
R_score
# Out:
# 0.1629417430978204

# %%
intercept = model.intercept_
print("Intercept:- ",intercept)
# Out:
# Intercept:-  [80.44547121]

# %%
slope = model.coef_
print("Slope:-",slope)
# Out:
# Slope:- [[0.96927982]]

# %%
y_pred = model.predict(x_test)
print("Predicted value:- ", y_pred)
# Out:
# Predicted value:-  [[122.12450359]
#  [144.41793951]
#  [134.72514129]
#  [137.63298075]
#  [123.09378341]
#  [145.38721934]
#  [116.30882465]
#  [141.51010005]
#  [132.78658164]
#  [137.63298075]
#  [126.9709027 ]
#  [133.75586146]
#  [120.18594394]
#  [113.40098518]
#  [134.72514129]
#  [129.87874217]
#  [120.18594394]
#  [140.54082022]
#  [141.51010005]
#  [132.78658164]
#  [142.47937987]
#  [123.09378341]
#  [144.41793951]
#  [114.37026501]
#  [120.18594394]
#  [148.29505881]
#  [137.63298075]
#  [136.66370093]
#  [127.94018253]
#  [122.12450359]
#  [122.12450359]
#  [119.21666412]
#  [142.47937987]
#  [130.84802199]
#  [130.84802199]
#  [124.06306324]
#  [136.66370093]
#  [137.63298075]
#  [135.69442111]
#  [149.26433863]
#  [138.60226058]
#  [146.35649916]
#  [130.84802199]
#  [135.69442111]
#  [123.09378341]
#  [130.84802199]
#  [123.09378341]
#  [132.78658164]
#  [140.54082022]
#  [130.84802199]
#  [142.47937987]
#  [131.81730182]
#  [154.11073774]
#  [130.84802199]
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y, color='blue')
plt.plot(x_test, y_pred, color='red', label='Linear Regression')
plt.xlabel('Age')
plt.ylabel('RestBP')
plt.legend()
